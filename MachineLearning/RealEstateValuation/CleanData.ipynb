# %% [markdown]
# ## Clean data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("RawData.csv")
df
# Out:
# C:\Users\DUC VAN\AppData\Local\Temp\ipykernel_32108\1498686140.py:1: DtypeWarning: Columns (5,31,32,34,35,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("RawData.csv")
#               ID    List ID Posted Time    Status Transaction Type  \
# 0      154269561  113584228  31/01/2025  accepted                s
# 1      164081534  122031985  07/02/2025  accepted                s
# 2      156854814  115807159  31/01/2025  accepted                s
# 3      163242245  121308677  31/01/2025  accepted                s
# 4      162985943  121088552  01/02/2025  accepted                s
# ...          ...        ...         ...       ...              ...
# 22903          0  123783254  24/03/2025         0                s
# 22904          0  123732634  21/03/2025         0                s
# 22905          0  123814515  25/03/2025         0                s
# 22906          0  122654608  06/02/2025         0                s
# 22907          0  121133105  22/03/2025         0                s
#
#       Seller Name   Seller ID  Region (Code) Region Name  Category  ...  \
# 0       Khang anh  24585559.0              3     Đà Nẵng      1040  ...
# 1        Minh trí  12588075.0              3     Đà Nẵng      1040  ...
# 2       Khang anh  24585559.0              3     Đà Nẵng      1040  ...
# 3       Khang anh  24585559.0              3     Đà Nẵng      1040  ...
# 4       Khang anh   4483578.0              3     Đà Nẵng      1040  ...
# ...           ...         ...            ...         ...       ...  ...
# 22903         NaN         NaN              0           0      1020  ...
# 22904         NaN         NaN              0           0      1020  ...
# 22905         NaN         NaN              0           0      1020  ...
# 22906         NaN         NaN              0           0      1020  ...
# 22907         NaN         NaN              0           0      1020  ...
#
#       Land Type (Text) Width (Text)      Ad ID     State  Floors  Rooms  \
# 0      Đất nông nghiệp    Ngang 4 m          0         0     0.0      0
# 1      Đất nông nghiệp    Ngang 5 m          0         0     0.0      0
# 2      Đất nông nghiệp   Ngang 10 m          0         0     0.0      0
# 3      Đất nông nghiệp    Ngang 5 m          0         0     0.0      0
# 4      Đất nông nghiệp    Ngang 5 m          0         0     0.0      0
# ...                ...          ...        ...       ...     ...    ...
# 22903              NaN          NaN  166111810  accepted     NaN      2
# 22904              NaN          NaN  166052754  accepted     1.0      2
# 22905              NaN          NaN  166147754  accepted     1.0      2
# 22906              NaN          NaN  164800816  accepted     2.0      3
# 22907              NaN          NaN  163037749  accepted     1.0      3
#
#       Toilets  Furnishing Sell         District    District Name
# 0         0.0              0.0  quận liên chiểu  Quận Liên Chiểu
# 1         0.0              0.0  quận liên chiểu  Quận Liên Chiểu
# 2         0.0              0.0  quận liên chiểu  Quận Liên Chiểu
# 3         0.0              0.0      quận cẩm lệ      Quận Cẩm Lệ
# 4         0.0              0.0  quận liên chiểu  Quận Liên Chiểu
# ...       ...              ...              ...              ...
# 22903     NaN              NaN     quận sơn trà     Quận Sơn Trà
# 22904     2.0              NaN      quận cẩm lệ      Quận Cẩm Lệ
# 22905     2.0              2.0      quận cẩm lệ      Quận Cẩm Lệ
# 22906     2.0              NaN    quận hải châu    Quận Hải Châu
# 22907     3.0              NaN    quận hải châu    Quận Hải Châu
#
# [22908 rows x 49 columns]

# %%
df = pd.read_csv("RawData.csv")

df = df[
    [
        "Category Name", "Longitude", "Latitude",
        "Area", "Width", "Length", "Land Type", 
        "Legal Status", "House Direction", "Property Features",
        "Floors", "Rooms", "Toilets", "Furnishing Sell", "Price", 
    ]
]

df_initial = df.copy()
df
# Out:
# C:\Users\DUC VAN\AppData\Local\Temp\ipykernel_32108\621236862.py:1: DtypeWarning: Columns (5,31,32,34,35,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("RawData.csv")
#       Category Name   Longitude   Latitude      Area  Width  Length  \
# 0               Đất  108.169500  16.065700  100.0000    4.0    25.0
# 1               Đất  108.158270  16.053888  102.0000    5.0    23.0
# 2               Đất  108.150700  16.058900  150.0000   10.0    15.0
# 3               Đất  108.172516  16.028736  100.0000    5.0    20.0
# 4               Đất  108.136940  16.077059  100.0000    5.0    20.0
# ...             ...         ...        ...       ...    ...     ...
# 22903         Nhà ở  108.237070  16.072918   42.7999    NaN     NaN
# 22904         Nhà ở  108.208176  15.991222  118.0000    5.0    23.5
# 22905         Nhà ở  108.229020  16.016070  100.0000    5.0    20.0
# 22906         Nhà ở  108.216780  16.034180   75.0000    5.0    15.0
# 22907         Nhà ở  108.211060  16.049389   83.0000    5.0    17.0
#
#        Land Type  Legal Status  House Direction Property Features  Floors  \
# 0              4             6              5.0              2; 4     0.0
# 1              4             6              8.0                 3     0.0
# 2              4             6              6.0           2; 3; 4     0.0
# 3              4             5              6.0           4; 2; 3     0.0
# 4              4             5              4.0              4; 2     0.0
# ...          ...           ...              ...               ...     ...
# 22903          0             1              NaN                 0     NaN
# 22904          0             1              2.0                 0     1.0
# 22905          0             1              5.0                 0     1.0
# 22906          0             1              2.0                 0     2.0
# 22907          0             1              8.0                 0     1.0
#
#        Rooms  Toilets  Furnishing Sell        Price
# 0          0      0.0              0.0    150000000
# 1          0      0.0              0.0    165000000
# 2          0      0.0              0.0    250000000
# 3          0      0.0              0.0    250000000
# 4          0      0.0              0.0    250000000
# ...      ...      ...              ...          ...
# 22903      2      NaN              NaN   3400000000
# 22904      2      2.0              NaN   3590000000
# 22905      2      2.0              2.0   4600000000
# 22906      3      2.0              NaN   5800000000
# 22907      3      3.0              NaN  14000000000
#
# [22908 rows x 15 columns]

# %% [markdown]
# ### Handling missing data

# %% [markdown]
# #### Lost data statistics

# %%
print(df.isnull().sum())
# Out:
# Category Name           0
# Longitude               0
# Latitude                0
# Area                    0
# Width                5242
# Length               8431
# Land Type               0
# Legal Status            0
# House Direction      9950
# Property Features    3519
# Floors               3573
# Rooms                   0
# Toilets              2514
# Furnishing Sell      5052
# Price                   0
# dtype: int64

# %% [markdown]
# #### For the Width and Length variables

# %% [markdown]
# *After the statistics we know that the area data is complete, then check if there is width but no length or vice versa, then use the area calculation formula. If both features are empty, the default is 5 for width and 5 for length*

# %%
# If Length is empty but Width exists, then calculate Length
df.loc[df["Length"].isna() & df["Width"].notna(), "Length"] = (
df["Area"] / df["Width"]
)

# If Width is empty but Length exists, then calculate Width
df.loc[df["Width"].isna() & df["Length"].notna(), "Width"] = (
df["Area"] / df["Length"]
)

# If both Width and Length are empty, set Width = 5 and calculate Length
missing_indexes = df[df["Width"].isna() & df["Length"].isna()].index
df.loc[missing_indexes, "Length"] = df.loc[missing_indexes, "Area"] / 5
df.loc[missing_indexes, "Width"] = 5

# %%
before_count = (df_initial["Width"].dropna().clip(0, 100) == 5).sum()
after_count = (df["Width"].dropna().clip(0, 100) == 5).sum()

# %% [markdown]
# *It is clear to see the big change in data distribution, but for land data, I think the above approach is reasonable.*

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df_initial["Width"].dropna().clip(0, 100).plot(kind='kde', ax=ax, color='blue', label="Before", linewidth=2)
df["Width"].dropna().clip(0, 100).plot(kind='kde', ax=ax, color='green', label="After", linewidth=2)
ax.set_xlim(0, 100)
ax.grid(True, linestyle="--", alpha=0.7)
ax.legend(loc='best')
ax.set_title("Distribution of Width")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df_initial["Length"].dropna().clip(0, 100).plot(kind='kde', ax=ax, color='blue', label="Before", linewidth=2)
df["Length"].dropna().clip(0, 100).plot(kind='kde', ax=ax, color='green', label="After", linewidth=2)
ax.set_xlim(0, 100)
ax.grid(True, linestyle="--", alpha=0.7)
ax.legend(loc='best')
ax.set_title("Distribution of Length")
plt.show()

# %% [markdown]
# #### For the feature variable *House Direction*, use the random method instead.

# %%
def replace_invalid_house_direction(direction):
    if pd.isna(direction):
        return random.randint(1, 8)
    return direction  

df["House Direction"] = df["House Direction"].apply(replace_invalid_house_direction)

# %% [markdown]
# *With this method we can retain the distribution trend of the feature*

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df_initial["House Direction"].dropna().plot(kind='kde', ax=ax, color='blue', label="Before")
df["House Direction"].dropna().plot(kind='kde', ax=ax, color='green', label="After")

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
ax.grid(True, linestyle="--", alpha=0.7)
ax.set_title("Distribution of House Direction")
plt.show()

# %% [markdown]
# #### For the *Property Features* variable, if the *land type* is residential land, the default *Property Features* has the value 3 (partly residential land), otherwise it is assumed to be 2 (non-residential land).

# %%
df.loc[(df["Land Type"] == 1) & (df["Property Features"].isna()), "Property Features"] = "3"
df.loc[(df["Land Type"] != 1) & (df["Property Features"].isna()), "Property Features"] = "4"
df
# Out:
#       Category Name   Longitude   Latitude      Area  Width    Length  \
# 0               Đất  108.169500  16.065700  100.0000    4.0  25.00000
# 1               Đất  108.158270  16.053888  102.0000    5.0  23.00000
# 2               Đất  108.150700  16.058900  150.0000   10.0  15.00000
# 3               Đất  108.172516  16.028736  100.0000    5.0  20.00000
# 4               Đất  108.136940  16.077059  100.0000    5.0  20.00000
# ...             ...         ...        ...       ...    ...       ...
# 22903         Nhà ở  108.237070  16.072918   42.7999    5.0   8.55998
# 22904         Nhà ở  108.208176  15.991222  118.0000    5.0  23.50000
# 22905         Nhà ở  108.229020  16.016070  100.0000    5.0  20.00000
# 22906         Nhà ở  108.216780  16.034180   75.0000    5.0  15.00000
# 22907         Nhà ở  108.211060  16.049389   83.0000    5.0  17.00000
#
#        Land Type  Legal Status  House Direction Property Features  Floors  \
# 0              4             6              5.0              2; 4     0.0
# 1              4             6              8.0                 3     0.0
# 2              4             6              6.0           2; 3; 4     0.0
# 3              4             5              6.0           4; 2; 3     0.0
# 4              4             5              4.0              4; 2     0.0
# ...          ...           ...              ...               ...     ...
# 22903          0             1              5.0                 0     NaN
# 22904          0             1              2.0                 0     1.0
# 22905          0             1              5.0                 0     1.0
# 22906          0             1              2.0                 0     2.0
# 22907          0             1              8.0                 0     1.0
#
#        Rooms  Toilets  Furnishing Sell        Price
# 0          0      0.0              0.0    150000000
# 1          0      0.0              0.0    165000000
# 2          0      0.0              0.0    250000000
# 3          0      0.0              0.0    250000000
# 4          0      0.0              0.0    250000000
# ...      ...      ...              ...          ...
# 22903      2      NaN              NaN   3400000000
# 22904      2      2.0              NaN   3590000000
# 22905      2      2.0              2.0   4600000000
# 22906      3      2.0              NaN   5800000000
# 22907      3      3.0              NaN  14000000000
#
# [22908 rows x 15 columns]

# %% [markdown]
# *Although the data distribution changes, it is not significant*

# %%
# Convert the 'Property Features' column into a list
df_initial["Property Features"] = df_initial["Property Features"].astype(str).str.split(";")
df["Property Features"] = df["Property Features"].astype(str).str.split(";")

# Expand each value in the array into separate rows
df_initial_exploded = df_initial.explode("Property Features")
df_exploded = df.explode("Property Features")

# Convert values to numeric type
df_initial_exploded["Property Features"] = pd.to_numeric(df_initial_exploded["Property Features"], errors="coerce")
df_exploded["Property Features"] = pd.to_numeric(df_exploded["Property Features"], errors="coerce")

# Plot KDE
fig = plt.figure()
ax = fig.add_subplot(111)

sns.kdeplot(df_initial_exploded["Property Features"].dropna(), ax=ax, color='blue', label="Before")
sns.kdeplot(df_exploded["Property Features"].dropna(), ax=ax, color='green', label="After")
ax.grid(True, linestyle="--", alpha=0.7)
ax.legend()
ax.set_title("Distribution of Property Features")
plt.show()

# %%
feature_mapping = {
    0: "No thing",
    1: "Frontage",
    2: "Back Expansion",
    3: "1 Part Residential",
    4: "No Residential",
    5: "Car Alley",
    6: "No Residential",
    7: "All Residential"
}

df["Property Features"] = df["Property Features"].apply(lambda x: [feature_mapping[int(num)] for num in x])
df.head()
# Out:
#   Category Name   Longitude   Latitude   Area  Width  Length  Land Type  \
# 0           Đất  108.169500  16.065700  100.0    4.0    25.0          4
# 1           Đất  108.158270  16.053888  102.0    5.0    23.0          4
# 2           Đất  108.150700  16.058900  150.0   10.0    15.0          4
# 3           Đất  108.172516  16.028736  100.0    5.0    20.0          4
# 4           Đất  108.136940  16.077059  100.0    5.0    20.0          4
#
#    Legal Status  House Direction  \
# 0             6              5.0
# 1             6              8.0
# 2             6              6.0
# 3             5              6.0
# 4             5              4.0
#
#                                    Property Features  Floors  Rooms  Toilets  \
# 0                   [Back Expansion, No Residential]     0.0      0      0.0
# 1                               [1 Part Residential]     0.0      0      0.0
# 2  [Back Expansion, 1 Part Residential, No Reside...     0.0      0      0.0
# 3  [No Residential, Back Expansion, 1 Part Reside...     0.0      0      0.0
# 4                   [No Residential, Back Expansion]     0.0      0      0.0
#
#    Furnishing Sell      Price
# 0              0.0  150000000
# 1              0.0  165000000
# 2              0.0  250000000
# 3              0.0  250000000
# 4              0.0  250000000

# %% [markdown]
# #### With the typical *Floors*, generally speaking, the first floor will usually have 1 bedroom and the upper floors will have 2, so the following formula will be applied

# %%
df['Floors'] = df.apply(lambda row: np.floor((row['Rooms'] - 1) / 2) + 1 if pd.isnull(row['Floors']) else row['Floors'], axis=1)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df_initial["Floors"].dropna().plot(kind='kde', ax=ax, color='blue', label="Before")
df["Floors"].dropna().plot(kind='kde', ax=ax, color='green', label="After")

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
ax.grid(True, linestyle="--", alpha=0.7)
ax.set_title("Distribution of Floors")
plt.show()

# %% [markdown]
# #### The number of bathrooms is equal to the number of floors

# %%
df['Toilets'] = df.apply(lambda row: row['Floors'] if pd.isna(row['Toilets']) else row['Toilets'], axis=1)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df_initial["Toilets"].dropna().plot(kind='kde', ax=ax, color='blue', label="Before")
df["Toilets"].dropna().plot(kind='kde', ax=ax, color='green', label="After")

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
ax.grid(True, linestyle="--", alpha=0.7)
ax.set_title("Distribution of Toilets")
plt.show()

# %% [markdown]
# #### For the feature variable *Furnishing Sell*, use the random method instead.

# %%
df["Furnishing Sell"] = df["Furnishing Sell"].apply(lambda x: np.random.randint(1, 5) if pd.isna(x) else x)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df_initial["Furnishing Sell"].dropna().plot(kind='kde', ax=ax, color='blue', label="Before")
df["Furnishing Sell"].dropna().plot(kind='kde', ax=ax, color='green', label="After")

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
ax.grid(True, linestyle="--", alpha=0.7)
ax.set_title("Distribution of Furnishing Sell")
plt.show()

# %% [markdown]
# #### Remove data with *Ward name* field as null value

# %%
# df = df.dropna(subset=["Ward Name"])

# %% [markdown]
# ##### Check for lost data

# %%
print(df.isnull().sum())
# Out:
# Category Name        0
# Longitude            0
# Latitude             0
# Area                 0
# Width                0
# Length               0
# Land Type            0
# Legal Status         0
# House Direction      0
# Property Features    0
# Floors               0
# Rooms                0
# Toilets              0
# Furnishing Sell      0
# Price                0
# dtype: int64

# %% [markdown]
# ### Exceptional data processing (outliers)

# %%
df_noOutliers = df.copy()

# %%
numerical_columns = ["Longitude", "Latitude" ,"Area", "Width", "Length", "Floors", "Rooms", "Toilets", "Price"]

plt.figure(figsize=(12, 8))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(3, 3, i)
    sns.histplot(data=df, x=col, bins=30)
    plt.ylabel('Sample')
    plt.xlabel(col)
    plt.xticks(fontsize=13)  
    plt.yticks(fontsize=13) 
    plt.tight_layout()

plt.show()

# %% [markdown]
# The data of *Area*, *Width*, *Length*, *Price* have skewed distribution.

# %% [markdown]
# #### Skewed distribution

# %%
cols = ["Longitude", "Latitude", "Area", "Width", "Length", "Floors", "Rooms", "Toilets", "Price"]

for col in cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    upper_bound = q3 + 3 * iqr  
    lower_bound = q1 - 3 * iqr  

    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# %%
cols = ["Longitude", "Latitude", "Area", "Width", "Length", "Floors", "Rooms", "Toilets", "Price"]

plt.figure(figsize=(18, 12))
for i, col in enumerate(cols, 1):
    plt.subplot(9, 2, 2*i-1) 
    sns.histplot(data=df_noOutliers, x=col, bins=30, color='blue', alpha=0.5, label='No Outliers')
    plt.ylabel('Count', fontsize = 15)
    plt.xlabel(col, fontsize = 15)   
    plt.xticks(fontsize=15)  
    plt.yticks(fontsize=15) 
    plt.title('No Outliers - ' + col)
    plt.legend()

    plt.subplot(9, 2, 2*i) 
    sns.histplot(data=df, x=col, bins=30, color='red', alpha=0.5, label='Outliers')
    plt.ylabel('Count', fontsize = 15)
    plt.xlabel(col, fontsize = 15)
    plt.xticks(fontsize=15)  
    plt.yticks(fontsize=15) 
    plt.title('Outliers - ' + col)
    plt.legend()

plt.tight_layout()
plt.show()

# %%
df.to_csv('CleanData.csv', index=False)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### Clean data reduces risk and errors

# %% [markdown]
# <li>Remove blank, incorrect, or noisy values ​​from the data set. This helps ensure that we only work with reliable and accurate information. </li>
# <li>When we encounter unusual or outlier values, outlier handling helps minimize the impact of these values ​​on the final results.</li>

# %% [markdown]
# #### Increase data consistency and uniformity

# %% [markdown]
# <li>Helps to bring the units of measurement into the same range, reducing the difference in proportions between variables. Standardization makes analysis and comparison between variables easier and more accurate. </li>
# <li>This is especially important when we want to compare the correlation between variables.</li>
