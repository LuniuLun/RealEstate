# %% [markdown]
# ## Clean data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("RawHouseData.csv")
df
# Out:
#           Ad ID    List ID Posted Time     State Transaction Type  Category  \
# 0     163637787  121648951  18/02/2025  accepted                s      1020
# 1     163960652  121927657  23/12/2024  accepted                s      1020
# 2     165107956  122918497  18/02/2025  accepted                s      1020
# 3     158445460  117175774  14/02/2025  accepted                s      1020
# 4     163594029  121617942  16/02/2025  accepted                s      1020
# ...         ...        ...         ...       ...              ...       ...
# 4622  161848385  120120463  10/01/2025  accepted                s      1020
# 4623  163146309  121229287  25/11/2024  accepted                s      1020
# 4624  164372077  122282304  03/02/2025  accepted                s      1020
# 4625  163799740  121788547  15/01/2025  accepted                s      1020
# 4626  163831107  121815398  19/12/2024  accepted                s      1020
#
#      Category Name Company Ad  \
# 0            Nhà ở       True
# 1            Nhà ở        NaN
# 2            Nhà ở       True
# 3            Nhà ở       True
# 4            Nhà ở       True
# ...            ...        ...
# 4622         Nhà ở       True
# 4623         Nhà ở        NaN
# 4624         Nhà ở       True
# 4625         Nhà ở       True
# 4626         Nhà ở        NaN
#
#                                                   Title  \
# 0     Bán nhà 2 tầng 2 mê đường Cách Mạng Tháng 8- k...
# 1     Bán nhà kiêt cách mang tháng 8 công năng 3 phò...
# 2     Bán tòa nhà đường Chế Lan Viên. Phường Mỹ An. ...
# 3            Nhà ba lá khu thể thao SHB đà sơn. Đà Nẵng
# 4             Lô đất có nhà mặt tiền khu hoà an tôn đản
# ...                                                 ...
# 4622  Villa Biệt Thự Biển Sơn Trà, Đà Nẵng – Diện Tí...
# 4623  Nhà cực kì hiếm . Với đất dài . Có thể kinh do...
# 4624  NHÀ MT NGUYỄN CÔNG TRỨ GẦN BIỂN PHẠM VĂN ĐỒNG ...
# 4625  CHỦ gởi Bán KHÁCH SẠN 11tầng Phố Tây AN THƯỢNG...
# 4626  Bán nhà : mặt tiền Hải Hồ Hải Châu Đà ...
#
#                                             Description  ...  \
# 0     Chính chủ gửi bán nhà 2tầng kiệt ô tô cách Mạn...  ...
# 1     Cân bán nhà kiệt cách mạng tháng 8 3phong ngủ ...  ...
# 2     Apparterment Chế Lan Viên 5tầng gồm 9 căn hộ c...  ...
# 3     Căn nhà cấp bốn hs ba lá . Dt 75m2 . \nCó 2pn....  ...
# 4     Lô đất mặt tiền đường 5,5m khu dân cư hoà an t...  ...
# ...                                                 ...  ...
# 4622  🌟 Villa 3 tầng đẳng cấp 5 sao, nằm gần ngã tư ...  ...
# 4623  BÁN NHÀ :\n* Địa chỉ    : 107 Nguyễn Thị Minh ...  ...
# 4624  Nhà mặt phố Nguyễn Công Trứ gần Biển Phạm Văn ...  ...
# 4625  CHỦ gởi Bán Toà KHÁCH SẠN 11tầng Khu Phố Tây A...  ...
# 4626  Bán nhà MT 3 tầng đường Hải TP Hồ Đà Nă...  ...
#
#                     Location  Floors Rooms  Toilets  Furnishing Sell  \
# 0     16.0141862,108.1988312     NaN     3      NaN              NaN
# 1     16.0122832,108.1992015     2.0     3      3.0              NaN
# 2       16.042668,108.245483     5.0     9      7.0              NaN
# 3     16.0466751,108.1539849     1.0     2      1.0              NaN
# 4     16.0482589,108.1754804     1.0     1      1.0              NaN
# ...                      ...     ...   ...      ...              ...
# 4622  16.0711903,108.2350928     3.0    11      7.0              NaN
# 4623  16.0735162,108.2182382     NaN     4      NaN              NaN
# 4624  16.0663954,108.2395365     NaN     3      3.0              2.0
# 4625  16.0512151,108.2461821    11.0    11      7.0              1.0
# 4626  16.0803384,108.2154566     3.0     4      5.0              2.0
#
#       Sold Ads Count Active Ads Count                         Seller Avatar  \
# 0                5.0             14.0   https://cdn.chotot.com/uac2/5328617
# 1                NaN              1.0   https://cdn.chotot.com/uac2/4271052
# 2                5.0              2.0   https://cdn.chotot.com/uac2/3126386
# 3               10.0              7.0   https://cdn.chotot.com/uac2/4483578
# 4                1.0             18.0  https://cdn.chotot.com/uac2/24585559
# ...              ...              ...                                   ...
# 4622            20.0              2.0   https://cdn.chotot.com/uac2/1235066
# 4623             NaN              NaN  https://cdn.chotot.com/uac2/28004113
# 4624             1.0             45.0  https://cdn.chotot.com/uac2/12163650
# 4625             NaN              NaN  https://cdn.chotot.com/uac2/25920951
# 4626             2.0              1.0   https://cdn.chotot.com/uac2/2604815
#
#           Post Time          Ward Name
# 0           hôm qua        Quận Cẩm Lệ
# 1     2 tháng trước        Quận Cẩm Lệ
# 2           hôm qua  Quận Ngũ Hành Sơn
# 3      5 ngày trước    Quận Liên Chiểu
# 4      3 ngày trước        Quận Cẩm Lệ
# ...             ...                ...
# 4622  1 tháng trước       Quận Sơn Trà
# 4623  3 tháng trước      Quận Hải Châu
# 4624   2 tuần trước       Quận Sơn Trà
# 4625  1 tháng trước  Quận Ngũ Hành Sơn
# 4626  2 tháng trước      Quận Hải Châu
#
# [4627 rows x 31 columns]

# %%
df = pd.read_csv("RawHouseData.csv")

df = df[
    [
        "Ward Name", "Street Name", "Longitude", "Latitude",
        "Area (m²)", "Width (m)", "Length (m)", 
        "Legal Status", "House Direction", "Floors", 
        "Rooms", "Toilets", "Furnishing Sell", "Price", 
    ]
]

df_initial = df.copy()
df
# Out:
#               Ward Name                        Street Name   Longitude  \
# 0           Quận Cẩm Lệ          Đường Cách Mạng Tháng Tám  108.198830
# 1           Quận Cẩm Lệ  Kiêt Cách Mạng Tháng 8 TP Đà Nẵng  108.199200
# 2     Quận Ngũ Hành Sơn                       Chế Lan Viên  108.245480
# 3       Quận Liên Chiểu                     Đường Trần Đức  108.153984
# 4           Quận Cẩm Lệ                           Khe cạn   108.175480
# ...                 ...                                ...         ...
# 4622       Quận Sơn Trà                Đường Phạm Văn Đồng  108.235090
# 4623      Quận Hải Châu         Đường Nguyễn Thị Minh Khai  108.218240
# 4624       Quận Sơn Trà                    NGUYỄN CÔNG TRỨ  108.239540
# 4625  Quận Ngũ Hành Sơn                 Đường An Thượng 30  108.246185
# 4626      Quận Hải Châu                             HẢI Hồ  108.215454
#
#        Latitude  Area (m²)  Width (m)  Length (m)  Legal Status  \
# 0     16.014187       65.0        NaN         NaN             1
# 1     16.012283       65.0        6.0        12.0             1
# 2     16.042667       90.0        4.5        21.0             1
# 3     16.046675       75.0        5.0        15.0             4
# 4     16.048260       80.0        4.0        20.0             5
# ...         ...        ...        ...         ...           ...
# 4622  16.071190      568.0       20.0         NaN             1
# 4623  16.073517      230.0        NaN        23.0             1
# 4624  16.066395      514.0       12.0        43.0             1
# 4625  16.051214      162.0        9.0        18.0             1
# 4626  16.080338       75.0        4.0        19.0             1
#
#       House Direction  Floors  Rooms  Toilets  Furnishing Sell        Price
# 0                 NaN     NaN      3      NaN              NaN      2650000
# 1                 6.0     2.0      3      3.0              NaN      2950000
# 2                 NaN     5.0      9      7.0              NaN     70000000
# 3                 7.0     1.0      2      1.0              NaN    440000000
# 4                 6.0     1.0      1      1.0              NaN    450000000
# ...               ...     ...    ...      ...              ...          ...
# 4622              NaN     3.0     11      7.0              NaN  45000000000
# 4623              8.0     NaN      4      NaN              NaN  45000000000
# 4624              NaN     NaN      3      3.0              2.0  46000000000
# 4625              3.0    11.0     11      7.0              1.0  50500000000
# 4626              6.0     3.0      4      5.0              2.0  72000000000
#
# [4627 rows x 14 columns]

# %% [markdown]
# ### Handling missing data

# %% [markdown]
# #### Lost data statistics

# %%
print(df.isnull().sum())
# Out:
# Ward Name             0
# Street Name           0
# Longitude             0
# Latitude              0
# Area (m²)             0
# Width (m)          1388
# Length (m)         2119
# Legal Status          0
# House Direction    2504
# Floors             1419
# Rooms                 0
# Toilets             990
# Furnishing Sell    1913
# Price                 0
# dtype: int64

# %% [markdown]
# #### For the Width (m) and Length (m) variables

# %% [markdown]
# *After the statistics we know that the area data is complete, then check if there is width but no length or vice versa, then use the area calculation formula. If both features are empty, the default is 5 for width and 5 for length*

# %%
# If Length (m) is empty but Width (m) exists, then calculate Length (m)
df.loc[df["Length (m)"].isna() & df["Width (m)"].notna(), "Length (m)"] = (
df["Area (m²)"] / df["Width (m)"]
)

# If Width (m) is empty but Length (m) exists, then calculate Width (m)
df.loc[df["Width (m)"].isna() & df["Length (m)"].notna(), "Width (m)"] = (
df["Area (m²)"] / df["Length (m)"]
)

# If both Width (m) and Length (m) are empty, set Width (m) = 5 and calculate Length (m)
missing_indexes = df[df["Width (m)"].isna() & df["Length (m)"].isna()].index
df.loc[missing_indexes, "Length (m)"] = df.loc[missing_indexes, "Area (m²)"] / 5
df.loc[missing_indexes, "Width (m)"] = 5

# %%
before_count = (df_initial["Width (m)"].dropna().clip(0, 100) == 5).sum()
after_count = (df["Width (m)"].dropna().clip(0, 100) == 5).sum()

# %% [markdown]
# *It is clear to see the big change in data distribution, but for land data, I think the above approach is reasonable.*

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df_initial["Width (m)"].dropna().clip(0, 100).plot(kind='kde', ax=ax, color='blue', label="Before", linewidth=2)
df["Width (m)"].dropna().clip(0, 100).plot(kind='kde', ax=ax, color='green', label="After", linewidth=2)
ax.set_xlim(0, 100)
ax.grid(True, linestyle="--", alpha=0.7)
ax.legend(loc='best')
ax.set_title("Distribution of Width (m)")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df_initial["Length (m)"].dropna().clip(0, 100).plot(kind='kde', ax=ax, color='blue', label="Before", linewidth=2)
df["Length (m)"].dropna().clip(0, 100).plot(kind='kde', ax=ax, color='green', label="After", linewidth=2)
ax.set_xlim(0, 100)
ax.grid(True, linestyle="--", alpha=0.7)
ax.legend(loc='best')
ax.set_title("Distribution of Length (m)")
plt.show()

# %% [markdown]
# #### For the feature variable *House Direction*, use the random method instead.

# %%
def replace_invalid_house_direction(direction):
    if pd.isna(direction):
        return random.randint(1, 8)
    return direction  

df["House Direction"] = df["House Direction"].apply(replace_invalid_house_direction)

# %% [markdown]
# *With this method we can retain the distribution trend of the feature*

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df_initial["House Direction"].dropna().plot(kind='kde', ax=ax, color='blue', label="Before")
df["House Direction"].dropna().plot(kind='kde', ax=ax, color='green', label="After")

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
ax.grid(True, linestyle="--", alpha=0.7)
ax.set_title("Distribution of House Direction")
plt.show()

# %% [markdown]
# *Although the data distribution changes, it is not significant*

# %% [markdown]
# #### With the typical *Floors*, generally speaking, the first floor will usually have 1 bedroom and the upper floors will have 2, so the following formula will be applied

# %%
df['Floors'] = df.apply(lambda row: np.floor((row['Rooms'] - 1) / 2) + 1 if pd.isna(row['Floors']) else row['Floors'], axis=1)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df_initial["Floors"].dropna().plot(kind='kde', ax=ax, color='blue', label="Before")
df["Floors"].dropna().plot(kind='kde', ax=ax, color='green', label="After")

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
ax.grid(True, linestyle="--", alpha=0.7)
ax.set_title("Distribution of Floors")
plt.show()

# %% [markdown]
# #### The number of bathrooms is equal to the number of floors

# %%
df['Toilets'] = df.apply(lambda row: row['Floors'] if pd.isna(row['Toilets']) else row['Toilets'], axis=1)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df_initial["Toilets"].dropna().plot(kind='kde', ax=ax, color='blue', label="Before")
df["Toilets"].dropna().plot(kind='kde', ax=ax, color='green', label="After")

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
ax.grid(True, linestyle="--", alpha=0.7)
ax.set_title("Distribution of Toilets")
plt.show()

# %% [markdown]
# #### For the feature variable *Furnishing Sell*, use the random method instead.

# %%
df["Furnishing Sell"] = df["Furnishing Sell"].apply(lambda x: np.random.randint(1, 5) if pd.isna(x) else x)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df_initial["Furnishing Sell"].dropna().plot(kind='kde', ax=ax, color='blue', label="Before")
df["Furnishing Sell"].dropna().plot(kind='kde', ax=ax, color='green', label="After")

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
ax.grid(True, linestyle="--", alpha=0.7)
ax.set_title("Distribution of Furnishing Sell")
plt.show()

# %% [markdown]
# #### Remove data with *Ward name* field as null value

# %%
# df = df.dropna(subset=["Ward Name"])

# %% [markdown]
# ##### Check for lost data

# %%
print(df.isnull().sum())
# Out:
# Ward Name          0
# Street Name        0
# Longitude          0
# Latitude           0
# Area (m²)          0
# Width (m)          0
# Length (m)         0
# Legal Status       0
# House Direction    0
# Floors             0
# Rooms              0
# Toilets            0
# Furnishing Sell    0
# Price              0
# dtype: int64

# %% [markdown]
# ### Exceptional data processing (outliers)

# %%
df_noOutliers = df.copy()

# %%
numerical_columns = ["Longitude", "Latitude" ,"Area (m²)", "Width (m)", "Length (m)", "Floors", "Rooms", "Toilets", "Price"]

plt.figure(figsize=(12, 8))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(3, 3, i)
    sns.histplot(data=df, x=col, bins=30)
    plt.ylabel('Sample')
    plt.xlabel(col)
    plt.xticks(fontsize=13)  
    plt.yticks(fontsize=13) 
    plt.tight_layout()

plt.show()

# %% [markdown]
# The data of *Area (m²)*, *Width (m)*, *Length (m)*, *Price* have skewed distribution.

# %% [markdown]
# #### Skewed distribution

# %%
cols = ["Longitude", "Latitude", "Area (m²)", "Width (m)", "Length (m)", "Floors", "Rooms", "Toilets", "Price"]

for col in cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    upper_bound = q3 + 4 * iqr 
    lower_bound = q1 - 4 * iqr 
    outliers = df[(df[col] > upper_bound) | (df[col] < lower_bound)]
    df.loc[df[col] > upper_bound, col] = upper_bound
    df.loc[df[col] < lower_bound, col] = lower_bound

# %%
cols = ["Longitude", "Latitude", "Area (m²)", "Width (m)", "Length (m)", "Floors", "Rooms", "Toilets", "Price"]

plt.figure(figsize=(18, 12))
for i, col in enumerate(cols, 1):
    plt.subplot(9, 2, 2*i-1) 
    sns.histplot(data=df_noOutliers, x=col, bins=30, color='blue', alpha=0.5, label='No Outliers')
    plt.ylabel('Count', fontsize = 15)
    plt.xlabel(col, fontsize = 15)   
    plt.xticks(fontsize=15)  
    plt.yticks(fontsize=15) 
    plt.title('No Outliers - ' + col)
    plt.legend()

    plt.subplot(9, 2, 2*i) 
    sns.histplot(data=df, x=col, bins=30, color='red', alpha=0.5, label='Outliers')
    plt.ylabel('Count', fontsize = 15)
    plt.xlabel(col, fontsize = 15)
    plt.xticks(fontsize=15)  
    plt.yticks(fontsize=15) 
    plt.title('Outliers - ' + col)
    plt.legend()

plt.tight_layout()
plt.show()

# %%
df.to_csv('CleanData.csv', index=False)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### Clean data reduces risk and errors

# %% [markdown]
# <li>Remove blank, incorrect, or noisy values ​​from the data set. This helps ensure that we only work with reliable and accurate information. </li>
# <li>When we encounter unusual or outlier values, outlier handling helps minimize the impact of these values ​​on the final results.</li>

# %% [markdown]
# #### Increase data consistency and uniformity

# %% [markdown]
# <li>Helps to bring the units of measurement into the same range, reducing the difference in proportions between variables. Standardization makes analysis and comparison between variables easier and more accurate. </li>
# <li>This is especially important when we want to compare the correlation between variables.</li>
