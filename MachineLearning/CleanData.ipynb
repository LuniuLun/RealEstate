# %% [markdown]
# ## Làm sạch dữ liệu

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import random
import matplotlib.pyplot as plt
import scipy.stats as stats
from datetime import datetime, timedelta
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("RawData.csv")
df
# Out:
#              ID    List ID Posted Time    Status Transaction Type  \
# 0     154269561  113584228  31/01/2025  accepted                s
# 1     164081534  122031985  07/02/2025  accepted                s
# 2     156854814  115807159  31/01/2025  accepted                s
# 3     163242245  121308677  31/01/2025  accepted                s
# 4     162985943  121088552  01/02/2025  accepted                s
# ...         ...        ...         ...       ...              ...
# 3218  164166442  122105081  01/01/2025  accepted                s
# 3219  164338766  122253496  08/01/2025  accepted                s
# 3220  163817823  121804172  09/01/2025  accepted                s
# 3221  164355152  122267719  09/01/2025  accepted                s
# 3222  164548257  122435411  17/01/2025  accepted                s
#
#            Seller Name  Seller ID  Region (Code) Region Name  Category  ...  \
# 0            Khang anh   24585559              3     Đà Nẵng      1040  ...
# 1             Minh trí   12588075              3     Đà Nẵng      1040  ...
# 2            Khang anh   24585559              3     Đà Nẵng      1040  ...
# 3            Khang anh   24585559              3     Đà Nẵng      1040  ...
# 4            Khang anh    4483578              3     Đà Nẵng      1040  ...
# ...                ...        ...            ...         ...       ...  ...
# 3218    Johnny Nguyễn    12984884              3     Đà Nẵng      1040  ...
# 3219         Chính Chủ   22921043              3     Đà Nẵng      1040  ...
# 3220   Tran ngoc thanh   12109157              3     Đà Nẵng      1040  ...
# 3221                Ry   24099488              3     Đà Nẵng      1040  ...
# 3222  Nguyễn Mạnh Hùng     270787              3     Đà Nẵng      1040  ...
#
#                                        First Image Link  \
# 0     https://cdn.chotot.com/39I61g4Z4HaQKXOJo4_MW1S...
# 1     https://cdn.chotot.com/Hsr-tGM2Rr24qj1WWtoGLDO...
# 2     https://cdn.chotot.com/9Ig90eUQZTlpbohXsaHacff...
# 3     https://cdn.chotot.com/YB5LYLM1jC3Ioy_54Zeg9wE...
# 4     https://cdn.chotot.com/wWdkqHNA151A5o-Lo7s6D5l...
# ...                                                 ...
# 3218  https://cdn.chotot.com/b1UIWiE_1lM5KfO-aYIvV62...
# 3219  https://cdn.chotot.com/xj-Iavw0SZmaZ2v5Al5IGmz...
# 3220  https://cdn.chotot.com/Bv1ffROcxEA6TvYQ519JHei...
# 3221  https://cdn.chotot.com/BwojnswKST9d5qVX2_YFaIw...
# 3222  https://cdn.chotot.com/mShvyZ9RNJq9Tz-_aT5DAnV...
#
#                                              Image List Number of Images  \
# 0     https://cdn.chotot.com/39I61g4Z4HaQKXOJo4_MW1S...                8
# 1     https://cdn.chotot.com/Hsr-tGM2Rr24qj1WWtoGLDO...                5
# 2     https://cdn.chotot.com/9Ig90eUQZTlpbohXsaHacff...                8
# 3     https://cdn.chotot.com/YB5LYLM1jC3Ioy_54Zeg9wE...               10
# 4     https://cdn.chotot.com/wWdkqHNA151A5o-Lo7s6D5l...                6
# ...                                                 ...              ...
# 3218  https://cdn.chotot.com/b1UIWiE_1lM5KfO-aYIvV62...                4
# 3219  https://cdn.chotot.com/xj-Iavw0SZmaZ2v5Al5IGmz...                6
# 3220  https://cdn.chotot.com/Bv1ffROcxEA6TvYQ519JHei...                3
# 3221  https://cdn.chotot.com/BwojnswKST9d5qVX2_YFaIw...                3
# 3222  https://cdn.chotot.com/mShvyZ9RNJq9Tz-_aT5DAnV...                3
#
#                                         Thumbnail Image  \
# 0     https://cdn.chotot.com/Trr4BbH7JLZnH-Ur7w7o7H4...
# 1     https://cdn.chotot.com/SoG8KUcnMwYDUADSsfYLQ_e...
# 2     https://cdn.chotot.com/XVe5iWlj4zqkUpk39SURzI3...
# 3     https://cdn.chotot.com/1ENRKLeyLCaq8xxE5h0ZB7H...
# 4     https://cdn.chotot.com/3rOmXj8yeL8XL-iQf8MzbCp...
# ...                                                 ...
# 3218  https://cdn.chotot.com/I8EBh4TxpIt0lvp8hPlpoXr...
# 3219  https://cdn.chotot.com/vqdhGdf-qOmiRQ9orGjGROv...
# 3220  https://cdn.chotot.com/SyNj5ELmnEgEfPGmklz0slk...
# 3221  https://cdn.chotot.com/DxGYU2YDFx1xLevF4H9G5QU...
# 3222  https://cdn.chotot.com/btnWMJVdBcuBVqgwNtstCaA...
#
#                                               Map Image             Ward Name  \
# 0     https://cdn.chotot.com/admincentre/location/16...       Phường Hòa Minh
# 1     https://cdn.chotot.com/admincentre/location/16...  Phường Hòa Khánh Nam
# 2     https://cdn.chotot.com/admincentre/location/16...  Phường Hòa Khánh Nam
# 3     https://cdn.chotot.com/admincentre/location/16...       Phường Hòa Phát
# 4     https://cdn.chotot.com/admincentre/location/16...  Phường Hòa Khánh Bắc
# ...                                                 ...                   ...
# 3218  https://cdn.chotot.com/admincentre/location/16...  Phường Hòa Cường Nam
# 3219  https://cdn.chotot.com/admincentre/location/16...       Phường Hòa Minh
# 3220  https://cdn.chotot.com/admincentre/location/16...     Phường Khuê Trung
# 3221  https://cdn.chotot.com/admincentre/location/15...        Phường Hoà Quý
# 3222  https://cdn.chotot.com/admincentre/location/16...       Phường Mân Thái
#
#      Property Features  Additional Features  Land Type (Text)  Width (Text)
# 0                 2; 4                  NaN   Đất nông nghiệp     Ngang 4 m
# 1                    3                  NaN   Đất nông nghiệp     Ngang 5 m
# 2              2; 3; 4                  NaN   Đất nông nghiệp    Ngang 10 m
# 3              4; 2; 3                  NaN   Đất nông nghiệp     Ngang 5 m
# 4                 4; 2                  NaN   Đất nông nghiệp     Ngang 5 m
# ...                ...                  ...               ...           ...
# 3218                 1                  NaN        Đất thổ cư    Ngang 55 m
# 3219               NaN                  NaN        Đất thổ cư           NaN
# 3220              1; 2                  NaN        Đất thổ cư   Ngang 4.5 m
# 3221               NaN                  NaN     Đất nền dự án     Ngang 5 m
# 3222               NaN                  NaN        Đất thổ cư    Ngang 27 m
#
# [3223 rows x 41 columns]

# %%
df = pd.read_csv("RawData.csv")

df = df[
    [
        "Ward Name", "Street Name", "Longitude", "Latitude",
        "Area (m²)", "Width (m)", "Length (m)", "Land Type", 
        "Legal Status", "House Direction", "Property Features", "Price"
    ]
]

df_initial = df.copy()
df
# Out:
#                  Ward Name           Street Name   Longitude   Latitude  \
# 0          Phường Hòa Minh         Thanh vinh 15  108.169500  16.065700
# 1     Phường Hòa Khánh Nam  Đường Hoàng Văn Thái  108.158270  16.053888
# 2     Phường Hòa Khánh Nam          Đường Đà Sơn  108.150700  16.058900
# 3          Phường Hòa Phát              Vũ lăng   108.172516  16.028736
# 4     Phường Hòa Khánh Bắc                Âu cơ   108.136940  16.077059
# ...                    ...                   ...         ...        ...
# 3218  Phường Hòa Cường Nam  Đường Trần Đăng Ninh  108.229570  16.031054
# 3219       Phường Hòa Minh       Phường Hòa Minh  108.169550  16.065733
# 3220     Phường Khuê Trung    Đường Đỗ Thúc Tịnh  108.211190  16.022854
# 3221        Phường Hoà Quý         phạm đình bân  108.233420  15.982958
# 3222       Phường Mân Thái  Đường Võ Nguyên Giáp  108.249610  16.089727
#
#       Area (m²)  Width (m)  Length (m)  Land Type  Legal Status  \
# 0         100.0        4.0        25.0          4             6
# 1         102.0        5.0        23.0          4             6
# 2         150.0       10.0        15.0          4             6
# 3         100.0        5.0        20.0          4             5
# 4         100.0        5.0        20.0          4             5
# ...         ...        ...         ...        ...           ...
# 3218     1350.0       55.0        25.0          1             1
# 3219     9123.0        NaN         NaN          1             1
# 3220       81.0        4.5        20.0          1             1
# 3221      100.0        5.0        20.0          2             1
# 3222     1044.0       27.0         NaN          1             1
#
#       House Direction Property Features         Price
# 0                 5.0              2; 4     150000000
# 1                 8.0                 3     165000000
# 2                 6.0           2; 3; 4     250000000
# 3                 6.0           4; 2; 3     250000000
# 4                 4.0              4; 2     250000000
# ...               ...               ...           ...
# 3218              1.0                 1  120000000000
# 3219              NaN               NaN  150000000000
# 3220              7.0              1; 2  295000000000
# 3221              5.0               NaN  325000000000
# 3222              1.0               NaN  396000000000
#
# [3223 rows x 12 columns]

# %% [markdown]
# ### Handling missing data

# %% [markdown]
# #### Lost data statistics

# %%
print(df.isnull().sum())
# Out:
# Ward Name               0
# Street Name             0
# Longitude               0
# Latitude                0
# Area (m²)               0
# Width (m)             532
# Length (m)            921
# Land Type               0
# Legal Status            0
# House Direction      1153
# Property Features     968
# Price                   0
# dtype: int64

# %% [markdown]
# #### For the Width (m) and Length (m) variables

# %% [markdown]
# *After the statistics we know that the area data is complete, then check if there is width but no length or vice versa, then use the area calculation formula. If both features are empty, the default is 5 for width and 5 for length*

# %%
# If Length (m) is empty but Width (m) exists, then calculate Length (m)
df.loc[df["Length (m)"].isna() & df["Width (m)"].notna(), "Length (m)"] = (
df["Area (m²)"] / df["Width (m)"]
)

# If Width (m) is empty but Length (m) exists, then calculate Width (m)
df.loc[df["Width (m)"].isna() & df["Length (m)"].notna(), "Width (m)"] = (
df["Area (m²)"] / df["Length (m)"]
)

# If both Width (m) and Length (m) are empty, set Width (m) = 5 and calculate Length (m)
missing_indexes = df[df["Width (m)"].isna() & df["Length (m)"].isna()].index
df.loc[missing_indexes, "Length (m)"] = df.loc[missing_indexes, "Area (m²)"] / 5
df.loc[missing_indexes, "Width (m)"] = 5

# %% [markdown]
# *It is clear to see the big change in data distribution, but for land data, I think the above approach is reasonable.*

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df_initial["Width (m)"].dropna().plot(kind='kde', ax=ax, color='blue', label="Before")
df["Width (m)"].dropna().plot(kind='kde', ax=ax, color='green', label="After")

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

ax.set_title("Distribution of Width (m)")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df_initial["Length (m)"].dropna().plot(kind='kde', ax=ax, color='blue', label="Before")
df["Length (m)"].dropna().plot(kind='kde', ax=ax, color='green', label="After")

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

ax.set_title("Distribution of Length (m)")
plt.show()

# %% [markdown]
# #### For the feature variable *House Direction*, use the random method instead.

# %%
def replace_invalid_house_direction(direction):
    if pd.isna(direction):
        return random.randint(1, 8)
    return direction  

df["House Direction"] = df["House Direction"].apply(replace_invalid_house_direction)

# %% [markdown]
# *With this method we can retain the distribution trend of the feature*

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df_initial["House Direction"].dropna().plot(kind='kde', ax=ax, color='blue', label="Before")
df["House Direction"].dropna().plot(kind='kde', ax=ax, color='green', label="After")

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

ax.set_title("Distribution of House Direction")
plt.show()

# %% [markdown]
# #### For the *Property Features* variable, if the *land type* is residential land, the default *Property Features* has the value 3 (partly residential land), otherwise it is assumed to be 2 (non-residential land).

# %%
df.loc[(df["Land Type"] == 1) & (df["Property Features"].isna()), "Property Features"] = "3"
df.loc[(df["Land Type"] != 1) & (df["Property Features"].isna()), "Property Features"] = "2"

# %% [markdown]
# *Although the data distribution changes, it is not significant*

# %%
# Convert the 'Property Features' column into a list
df_initial["Property Features"] = df_initial["Property Features"].astype(str).str.split(";")
df["Property Features"] = df["Property Features"].astype(str).str.split(";")

# Expand each value in the array into separate rows
df_initial_exploded = df_initial.explode("Property Features")
df_exploded = df.explode("Property Features")

# Convert values to numeric type
df_initial_exploded["Property Features"] = pd.to_numeric(df_initial_exploded["Property Features"], errors="coerce")
df_exploded["Property Features"] = pd.to_numeric(df_exploded["Property Features"], errors="coerce")

# Plot KDE
fig = plt.figure()
ax = fig.add_subplot(111)

sns.kdeplot(df_initial_exploded["Property Features"].dropna(), ax=ax, color='blue', label="Before")
sns.kdeplot(df_exploded["Property Features"].dropna(), ax=ax, color='green', label="After")

ax.legend()
ax.set_title("Distribution of Property Features")
plt.show()

# %% [markdown]
# ##### Check for lost data

# %%
print(df.isnull().sum())
# Out:
# Ward Name            0
# Street Name          0
# Longitude            0
# Latitude             0
# Area (m²)            0
# Width (m)            0
# Length (m)           0
# Land Type            0
# Legal Status         0
# House Direction      0
# Property Features    0
# Price                0
# dtype: int64

# %% [markdown]
# ### Xử lí dữ liệu ngoại lệ (outliers)

# %%
df_noOutliers = df

# %%
numerical_columns = ["Area (m²)",	"Width (m)",	"Length (m)", "Price"]

plt.figure(figsize=(12, 8))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(2, 2, i)
    sns.histplot(data=df, x=col, bins=30)
    plt.ylabel('Sample')
    plt.xlabel(col)
    plt.xticks(fontsize=13)  
    plt.yticks(fontsize=13) 
    plt.tight_layout()

plt.show()

# %% [markdown]
# The data of *Area (m²)*, *Width (m)*, *Length (m)*, *Price* have skewed distribution.

# %% [markdown]
# #### Phân phối lệch

# %%
cols = ["Area (m²)",	"Width (m)",	"Length (m)", "Price"]

for col in cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    upper_bound = q3 + 4 * iqr 
    lower_bound = q1 - 4 * iqr 
    outliers = df[(df[col] > upper_bound) | (df[col] < lower_bound)]
    df.loc[df[col] > upper_bound, col] = upper_bound
    df.loc[df[col] < lower_bound, col] = lower_bound

# %%
cols = ["Area (m²)",	"Width (m)",	"Length (m)", "Price"]

plt.figure(figsize=(18, 12))
for i, col in enumerate(cols, 1):
    plt.subplot(6, 2, 2*i-1) 
    sns.histplot(data=df_noOutliers, x=col, bins=30, color='blue', alpha=0.5, label='No Outliers')
    plt.ylabel('Count', fontsize = 15)
    plt.xlabel(col, fontsize = 15)   
    plt.xticks(fontsize=15)  
    plt.yticks(fontsize=15) 
    plt.title('No Outliers - ' + col)
    plt.legend()

    plt.subplot(6, 2, 2*i) 
    sns.histplot(data=df, x=col, bins=30, color='red', alpha=0.5, label='Outliers')
    plt.ylabel('Count', fontsize = 15)
    plt.xlabel(col, fontsize = 15)
    plt.xticks(fontsize=15)  
    plt.yticks(fontsize=15) 
    plt.title('Outliers - ' + col)
    plt.legend()

plt.tight_layout()
plt.show()

# %%
df.to_csv('CleanData.csv', index=False)

# %% [markdown]
# ## Conclusion
